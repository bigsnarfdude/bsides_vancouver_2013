# %% [markdown]
# ## Next Steps - Where do you go from here?

# %%
from IPython.core.display import Image
from IPython.core.display import HTML
from IPython.lib.display import YouTubeVideo

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Google Rapid Response - GRR

# %%
# !open https://code.google.com/p/grr/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Keep the conversation going on Twitter

# %%
# !open https://twitter.com/bigsnarfdude

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Find all the material on this talk on Github

# %%
# !open https://github.com/bigsnarfdude

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %%
Image(filename="/Users/antigen/Desktop/bigsnarfhadoopstack1.png")

# %%
Image(filename="/Users/antigen/Desktop/bigsnarfjourney.png")

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Hadoop meets Sleuthkit

# %%
# !open http://www.sleuthkit.org/tsk_hadoop/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Python meets log2timeline

# %%
# !open http://plaso.kiddaland.net/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## DFIR and Machine Learning - Match made in heaven waiting to happen

# %%
# !open http://scikit-learn.org/stable/

# %%
# !open http://drops.dagstuhl.de/opus/volltexte/2013/3790/pdf/dagrep_v002_i009_p109_s12371.pdf

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Fuzzy Hashing with ssdeep

# %%
# !open http://ssdeep.sourceforge.net/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Thanks to Hacker School NYC

# %% [markdown]
# Hacker School is a three-month, full-time school in New York for becoming a better programmer. We're free as in beer, and provide space, a little structure, time to focus, and a friendly community of smart builders dedicated to self-improvement.

# %%
# !open https://www.hackerschool.com/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Run and embed inline plots and graphs

# %%
x = linspace(0, 2*pi)
plot(x, sin(x), label=r'$\sin(x)$')
plot(x, cos(x), 'ro', label=r'$\cos(x)$')
title(r'Two familiar functions')
#legend()

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Create images and graphs from complicated arrays

# %%
X = np.array([0,1,2,3,4])
Y = np.array([3,5,4,6,7])

# %%
plot(X,Y)

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Here is the documentation I used in this presentation

# %%
# !open https://volatility.googlecode.com/svn/branches/scudette/docs/tutorial.html

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Comparing MD5 APT1 Hashes agains files

# %%
apt1_md5s = open('/root/Desktop/APT1md5').readlines()
apt1_set_list = set([i.strip('\n') for i in apt1_md5s[0:]])
apt1_set_list
# Out:
# set(['d3f9d4bc51db1e602093e3003fc789d9',
#      'c4f144febf16ff8f36df15353d5347ce',
#      'b883f8e5a1420d1f511266b9253c11c4',
#      '67f62f5accfeacf5e828c3b3905248fe',
#      '45aa4177bb42eb3ded5edf397a4aaded',
#      'f172ff6b65140f342e6ee51966ea3c4c',
#      '5cd578614afb50b925008b68b3accdb9',
#      '75dad1ccabae8adeb5bae899d0c630f8',
#      'ae1dda87cc5998de79ecb68527bbd191',
#      'a44312eb63de002383a57b5a93271cdc',
#      '973f4a238d6d19bdc7b42977b07b9cef',
#      '390d1f2a620912104f53c034c8aef14b',
#      'ab445da3ee4e81a84d644476f669d35c',
#      '5e686bd284022e35559a9c6118df8f1e',
#      '52509abd1cc7b7fb391b19929e0d99c0',
#      'd9b1c95fb4424cf69a0ac8e40b3ab39b',
#      '2080f463388aebe6deb7edf11c01f7ff',
#      'bd15714360c12ffca4c3c1e86fc69d0e',
#      'c0134285a276ab933e2a2b9b33b103cd',
#      '98409dbf432419024dbf028c004344c1',
#      '70c10f8b4dcd01b07be6cfb4df0d3348',
#      'b43266a047b2895399f4883cfe37c089',
#      '6ab7fa8e5fb63b8d0723387d0a1ffe6d',
# ...

# %%
memory_executables_MD5 = open('/root/Desktop/asdf/file.txt').readlines()
memory_executables_MD5_set_list = set([i.split()[0] for i in memory_executables_MD5[0:]])
memory_executables_MD5_set_list
# Out:
# set(['ad52ce0deed954e406b61ab1d87ca24d',
#      '1176b7d01ce6a2fec0ef3f416278f97a',
#      '679d32f721b598f836da065eed0c1faa',
#      'e1e00c2d5815e4129d8ac503f6fac095',
#      '1db270bbd208f961c1ebe295364c8210',
#      '86c9a5fbf7290a75a58d0d7c4fccae79',
#      '33829e6729a29f86d93d294d957d96cd',
#      '1e1e666de0edb305a7601a9e6f52c132',
#      '5aa8633012b69d27948f112fb39fa85a',
#      '8238fd7876f331d47b97bd0e9ae4e221',
#      '68c3c4ee9c041eb0c88ec0dd22d734d5',
#      '21c183cdabccc7675b50258313812bc7',
#      '107a0f816d01c1ca04029edc3c92a329',
#      'ba1c4426cf94a7d631a85d978b28fb19',
#      '85a4ee249d8e5302a620b392d7ce5929',
#      'b282321a01be5e46a1ba3ecfff4729ee',
#      '7ffcad8757f851f2f5e9ce6ad1a14563',
#      '8960f6cd4b63a3789e57f949f06b85e0',
#      'e7a35f1f6f827c21c1bb48e6977aae72',
#      'e34432676aed50096e79571cfa67a727',
#      '6dc3485fc241a1fd5e913e7be77f10bc',
#      'b25a395ab299bafdc99409ca9055952f',
#      '7b62da1a65ffc31c55da778b276ad1e2',
# ...

# %% [markdown]
# ## These sets are compared and any executables that are in APT1 hashes are returned

# %%
apt1_set_list.intersection(memory_executables_MD5_set_list)
# Out:
# set([])

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Comparing MD5 APT1 Hashes against files

# %% [markdown]
# "To denote the identity of a malicious binary or executable, analysts often use cryptographic hashing, which computes a hash value on a block of data, such that an accidental or intentional change to the data will change the hash value...Fuzzy hashes and other block/rolling hash methods provide a continuous stream of hash values for a rolling window over the binary. These methods produce hash values that allow analysts to assign a percentage score that indicates the amount of content that the two files have in common. A recent type of fuzzy hashing, known as context triggered piecewise hashing, has gained enormous popularity in malware detection and analysis in the form of an open-source tool called ssdeep." http://blog.sei.cmu.edu/post.cfm/fuzzy-hashing-techniques-in-applied-malware-analysis

# %% [markdown]
# ## Compare MD5 to Whitelisted MD5s

# %%
# !open http://www.nsrl.nist.gov/Downloads.htm

# %% [markdown]
# ## Compare MD5 to Blacklisted MD5s

# %%
# !open http://virusshare.com/hashes/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Moar Reading on Fuzzy Hashing

# %%
# !open http://threatthoughts.com/2013/01/28/konig-malware-graph-theory-and-fuzzy-hashes/

# %%
# !open http://ssdeep.sourceforge.net/

# %%
# !open http://jessekornblum.com/presentations/cdfsl07.pdf

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Volatility Labs - Month of Volatility Plugins

# %%
# !open http://volatility-labs.blogspot.ca/2012/09/movp-11-logon-sessions-processes-and.html

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Paper of Android Memory Analysis with Volatility

# %%
# !open http://computer-forensics.sans.org/summit-archives/2012/android-mind-reading-memory-acquisition-and-analysis-with-lime-and-volatility.pdf

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Tool for monitoring installation routines of programs

# %%
# !open http://www.martau.com/installation-monitor.php

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %%
HTML("<iframe src=https://volatility.googlecode.com/svn/branches/scudette/docs/index.html width=1000 height=400 /iframe>")
# Out:
# <iframe src=https://volatility.googlecode.com/svn/branches/scudette/docs/index.html width=1000 height=400 /iframe>

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Cuckoobox, Volatility, Yara Video on YouTube

# %%
YouTubeVideo(id="mxGnjTlufAA", width=600, height=400)
# Out:
#             <iframe
#                 width="600"
#                 height="400"
#                 src="http://www.youtube.com/embed/mxGnjTlufAA"
#                 frameborder="0"
#                 allowfullscreen
#             ></iframe>

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Awesome Potential of Visualization for memory space and processes

# %%
# !open http://pinterest.com/pin/95138610848260436/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Books over blogs

# %%
# !open http://pinterest.com/dangleebits/

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## .

# %% [markdown]
# ## Awesome Team Responsible for Volatility

# %%
# !open https://code.google.com/p/volatility/wiki/VolatilityTeam
